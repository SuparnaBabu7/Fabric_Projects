# %% [markdown]
# # Read the JSON file as a Dataframe

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.functions import *
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 3, Finished, Available, Finished)

# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, dada4d71-48fa-4b68-9696-00602f4a5f6c)

# %% [markdown]
# # Read the JSON file as a Dataframe

# %%
df = df.select("value")
display(df)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6fa310f3-8980-46d0-ad35-abfac97740d9)

# %% [markdown]
# # Explode the JSON column

# %%
df_exploded = df.select(explode(df["value"]).alias("json_object"))
display(df_exploded)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 16f78c6d-2e6f-40bc-aad6-4cfc2c399480)

# %% [markdown]
# # Explode the JSON column

# %%
json_list = df_exploded.toJSON().collect()
print(json_list)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 7, Finished, Available, Finished)
# ['{"json_object":{"about":[{"name":"Zodiac Sign","readLink":"https://api.bing.microsoft.com/api/v7/entities/c7c67655-09b0-e7f9-f01b-80d24c61e27d"},{"name":"Aries","readLink":"https://api.bing.microsoft.com/api/v7/entities/40aecf93-af69-db94-fd72-78f1f702b9ef"},{"name":"Taurus","readLink":"https://api.bing.microsoft.com/api/v7/entities/6e5d800c-f9a1-3047-3dd7-1cd6d55f1041"},{"name":"Astrology","readLink":"https://api.bing.microsoft.com/api/v7/entities/4f133e90-81c0-2614-dbda-5651028a715f"}],"datePublished":"2025-04-25T14:00:00.0000000Z","description":"Indian cricket matches transcend mere sports, evolving into a passionate religion fueled by fervent fans. This article humorously dissects how each zo","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.zkj8XnqU3reME_sM-05sUS&pid=News","height":379,"width":700}},"mentions":[{"name":"Existentialism"},{"name":"Zodiac"},{"name":"Cricket"}],"name":"Zodiac Signs at a Cricket Match: From Sixes to Existential Crises","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.VBzHmoY4z9NL3FbRonyM1w&pid=news"}},"name":"The Times of India on MSN.com"}],"url":"https://www.msn.com/en-in/sports/cricket/zodiac-signs-at-a-cricket-match-from-sixes-to-existential-crises/ar-AA1DC0Cz"}}', '{"json_object":{"about":[{"name":"Chennai","readLink":"https://api.bing.microsoft.com/api/v7/entities/d97acf5c-0a2b-cd2c-e895-ef8aa64b883b"},{"name":"MS Dhoni","readLink":"https://api.bing.microsoft.com/api/v7/entities/0ce92e7f-4158-4cec-9040-57a76e5b61dd"},{"name":"Chennai Super Kings","readLink":"https://api.bing.microsoft.com/api/v7/entities/38d30bc5-bbfa-0d0a-000e-63278c5821cc"},{"name":"Sunrisers Hyderabad","readLink":"https://api.bing.microsoft.com/api/v7/entities/2af4fe1c-caf3-4cfc-a04a-5cfa35909ac8"},{"name":"M. A. Chidambaram Stadium","readLink":"https://api.bing.microsoft.com/api/v7/entities/767bb648-9de1-0205-2715-f6227f2a00f0"},{"name":"Mumbai Indians","readLink":"https://api.bing.microsoft.com/api/v7/entities/d3621dd7-dfc6-80a7-d3fd-79c88af2f503"}],"category":"Sports","datePublished":"2025-04-25T10:37:00.0000000Z","description":"Catch latest updates from MS Dhoni\'s 400th T20 as Chennai Super Kings face SunRisers Hyderabad at the MA Chidambaram Stadium at Chepauk today.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.YS2sx03gPqOwZLjdIR4byy&pid=News","height":393,"width":700}},"name":"CSK vs SRH LIVE Cricket Score, IPL 2025: Chennai faces do-or-die test in Dhoni’s 400th T20; Toss, Playing XI updates","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.KAwemXIpD5l2nQRDmYLy2w&pid=news"}},"name":"The Indian Express"}],"url":"https://indianexpress.com/article/sports/cricket/csk-vs-srh-live-score-2025-ipl-43th-match-live-cricket-score-updates-chennai-super-kings-vs-sunrisers-hyderabad-ms-dhoni-travis-head-9965292/"}}', '{"json_object":{"about":[{"name":"Rahul Dravid","readLink":"https://api.bing.microsoft.com/api/v7/entities/e7a42d68-16aa-7f2b-e1ee-0f3049bf3695"},{"name":"Sunil Gavaskar","readLink":"https://api.bing.microsoft.com/api/v7/entities/25711a2c-7c17-5a4a-d1a5-a60bb0423701"},{"name":"Rajasthan Royals","readLink":"https://api.bing.microsoft.com/api/v7/entities/53c34777-c3c7-197d-22ec-51e3a9f57bfd"},{"name":"Sanju Samson","readLink":"https://api.bing.microsoft.com/api/v7/entities/a985193a-1d63-3cfc-bded-f9d12d1ee52b"},{"name":"Rajasthan","readLink":"https://api.bing.microsoft.com/api/v7/entities/58d414c6-9557-d15b-60ff-52f256e32345"},{"name":"M. Chinnaswamy Stadium","readLink":"https://api.bing.microsoft.com/api/v7/entities/85ec3897-c3ed-4c21-dd73-318a80fbd468"}],"datePublished":"2025-04-25T08:01:00.0000000Z","description":"Gavaskar lamented Rajasthan\'s structure as a major flaw in the team\'s approach this season, banking on youngsters to do the heavy lifting.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.-xvhqcQ4wokjMdaYiioGhy&pid=News","height ...

# %% [markdown]
# # Explode the JSON column

# %%
print(json_list[0])
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 8, Finished, Available, Finished)
# {"json_object":{"about":[{"name":"Zodiac Sign","readLink":"https://api.bing.microsoft.com/api/v7/entities/c7c67655-09b0-e7f9-f01b-80d24c61e27d"},{"name":"Aries","readLink":"https://api.bing.microsoft.com/api/v7/entities/40aecf93-af69-db94-fd72-78f1f702b9ef"},{"name":"Taurus","readLink":"https://api.bing.microsoft.com/api/v7/entities/6e5d800c-f9a1-3047-3dd7-1cd6d55f1041"},{"name":"Astrology","readLink":"https://api.bing.microsoft.com/api/v7/entities/4f133e90-81c0-2614-dbda-5651028a715f"}],"datePublished":"2025-04-25T14:00:00.0000000Z","description":"Indian cricket matches transcend mere sports, evolving into a passionate religion fueled by fervent fans. This article humorously dissects how each zo","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.zkj8XnqU3reME_sM-05sUS&pid=News","height":379,"width":700}},"mentions":[{"name":"Existentialism"},{"name":"Zodiac"},{"name":"Cricket"}],"name":"Zodiac Signs at a Cricket Match: From Sixes to Existential Crises","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.VBzHmoY4z9NL3FbRonyM1w&pid=news"}},"name":"The Times of India on MSN.com"}],"url":"https://www.msn.com/en-in/sports/cricket/zodiac-signs-at-a-cricket-match-from-sixes-to-existential-crises/ar-AA1DC0Cz"}}

# %%
import json
news_json = json.loads(json_list[0])
print(news_json)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 9, Finished, Available, Finished)
# {'json_object': {'about': [{'name': 'Zodiac Sign', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/c7c67655-09b0-e7f9-f01b-80d24c61e27d'}, {'name': 'Aries', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/40aecf93-af69-db94-fd72-78f1f702b9ef'}, {'name': 'Taurus', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/6e5d800c-f9a1-3047-3dd7-1cd6d55f1041'}, {'name': 'Astrology', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/4f133e90-81c0-2614-dbda-5651028a715f'}], 'datePublished': '2025-04-25T14:00:00.0000000Z', 'description': 'Indian cricket matches transcend mere sports, evolving into a passionate religion fueled by fervent fans. This article humorously dissects how each zo', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.zkj8XnqU3reME_sM-05sUS&pid=News', 'height': 379, 'width': 700}}, 'mentions': [{'name': 'Existentialism'}, {'name': 'Zodiac'}, {'name': 'Cricket'}], 'name': 'Zodiac Signs at a Cricket Match: From Sixes to Existential Crises', 'provider': [{'_type': 'Organization', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.VBzHmoY4z9NL3FbRonyM1w&pid=news'}}, 'name': 'The Times of India on MSN.com'}], 'url': 'https://www.msn.com/en-in/sports/cricket/zodiac-signs-at-a-cricket-match-from-sixes-to-existential-crises/ar-AA1DC0Cz'}}

# %%
print(news_json['json_object']['description'])
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 10, Finished, Available, Finished)
# Indian cricket matches transcend mere sports, evolving into a passionate religion fueled by fervent fans. This article humorously dissects how each zo

# %%
print(news_json["json_object"]["name"])
print(news_json["json_object"]["description"])
print(news_json["json_object"]["category"])
print(news_json["json_object"]["url"])
print(news_json["json_object"]["image"]["thumbnail"]["contentUrl"])
print(news_json["json_object"]["provider"][0]["name"])
print(news_json["json_object"]["datePublished"])
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, 11, Finished, Available, Finished)
# Zodiac Signs at a Cricket Match: From Sixes to Existential Crises
# Indian cricket matches transcend mere sports, evolving into a passionate religion fueled by fervent fans. This article humorously dissects how each zo
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 print(news_json["json_object"]["name"])
#       2 print(news_json["json_object"]["description"])
# ----> 3 print(news_json["json_object"]["category"])
#       4 print(news_json["json_object"]["url"])
#       5 print(news_json["json_object"]["image"]["thumbnail"]["contentUrl"])
#
# KeyError: 'category'

# %%
#title
#description
#category
#image
#url
#provider
#datePublished
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %% [markdown]
# # Processing the JSON property to List

# %%
title = []
description = []
category = []
url =[]
image = []
provider = []
datePublished =[]


# Process each JSON object in the list
for json_str in json_list:
    try:
        # Parse the JSON string into a dictionary
        article = json.loads(json_str)

        if article["json_object"].get("category") and article["json_object"].get("image", {}).get("thumbnail", {}).get("contentUrl"):
        
            #Extract information from the dictionary
            title.append(article["json_object"]["name"])
            description.append(article["json_object"]["description"])
            category.append(article["json_object"]["category"])
            url.append(article["json_object"]["url"])
            image.append(article["json_object"]["image"]["thumbnail"]["contentUrl"])
            provider.append(article["json_object"]["provider"][0]['name'])
            datePublished.append(article["json_object"]["datePublished"])

    except Exception as e:
        print(f"Error processing JSON object: {e}")
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %% [markdown]
# # Converting the List to a Dataframe

# %%
from pyspark.sql.types import StructField
# Combine the lists
data = list(zip(title,description,category,url,image,provider,datePublished))

# define schema
schema = StructType([
    StructField("title", StringType(), True),
    StructField("description", StringType(), True),
    StructField("category",StringType(), True),
    StructField("url",StringType(), True),
    StructField("image",StringType(), True),
    StructField("provider",StringType(), True),
    StructField("datePublished",StringType(), True)
])
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %%
#create dataframe
df_cleaned = spark.createDataFrame(data, schema=schema)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %%
display(df_cleaned)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %% [markdown]
# # Processing the Date column

# %%
from pyspark.sql.functions import to_date, date_format

df_cleaned_final = df_cleaned.withColumn("datePublished", date_format(to_date("datePublished"), "dd-MM-yyyy"))
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %%
display(df_cleaned_final)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)

# %% [markdown]
# # Writing the Final Dataframe to the Lakehouse DB in a Delta format

# %%
from pyspark.sql.utils import AnalysisException

try:

    table_name = 'Bingnews_LH.tbl_latest_news'

    df_cleaned_final.write.format("delta").saveAsTable(table_name)

except AnalysisException:

    print("Table Already Exists")

    df_cleaned_final.createOrReplaceTempView("vw_df_cleaned_final")

    spark.sql(f"""  MERGE INTO {table_name} target_table
                    USING vw_df_cleaned_final source_view

                    ON source_view.url = target_table.url
                    
                    WHEN MATCHED AND 
                    source_view.title <> target_table.title OR
                    source_view.description <> target_table.description OR
                    source_view.category <> target_table.category OR
                    source_view.image <> target_table.image OR
                    source_view.provider <> target_table.provider OR
                    source_view.datePublished <> target_table.datePublished   

                    THEN UPDATE SET *

                    WHEN NOT MATCHED THEN INSERT *

                """)
# Out:
# StatementMeta(, 168731a7-0651-4610-b4ec-f84fbacc31c9, -1, Cancelled, , Cancelled)
